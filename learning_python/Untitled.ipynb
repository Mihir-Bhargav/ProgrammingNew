# %%
2+2
# Out:
# 4

# %%
3 + 5
# Out:
# 8

# %% [markdown]
# # Assistant
# The error occurs because there's a syntax error in the condition of your if statement. The modulo operator `%` requires two operands, but in your code, it's missing the right operand.
#
# Would you like me to provide the corrected code?

# %%
number = input("Plese enter a number")
print(number)
# Out:
# Plese enter a number 10
# 10

# %%
number = input("Plese enter a number")
if number % == 0:
    print("Even")

else:
    print("odd")
# Out:
#   Cell In[5], line 2
#     if number % == 0:
#                 ^
# SyntaxError: invalid syntax

# %%
number = int(input("Please enter a number: "))
if number % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Please enter a number:  bn
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 number = int(input("Please enter a number: "))
#       2 if number % 2 == 0:
#       3     print("Even")
#
# ValueError: invalid literal for int() with base 10: 'bn'

# %% [markdown]
# # Assistant
# The error occurs because there's a syntax error in the condition of your if statement. The modulo operator `%` requires two operands, but in your code, it's missing the right operand.
#
# Would you like me to provide the corrected code?
